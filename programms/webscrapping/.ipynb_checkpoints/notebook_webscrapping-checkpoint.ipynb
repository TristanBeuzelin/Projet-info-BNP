# %% [markdown]
# # __Webscapping processes for gathering prices over Rungis website__
#
# Here we present the different stages we went through to gather data for our simulations.
#
# First we started to import the various libraries. The most important here is `BeatifulSoup`that is used to navigate through the HTML code we previously fetched with `urllib.request`.

# %%
from bs4 import BeautifulSoup
import urllib.request
import csv
import pandas as pd 
import numpy as np 
import os
import threading

# %%
urlpage = "https://rnm.franceagrimer.fr/prix?FRUITS-ET-LEGUMES" #Defining the URL for the base

page = urllib.request.urlopen(urlpage) #Fecthing the page

soup = BeautifulSoup(page, 'html.parser') #Fetching the HTML code

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="fr">
# <head>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <link href="/css/basernm.css?051020" rel="stylesheet" type="text/css"/>
# <script async="" src="/css/basernm.js?270919"></script>
# <link href="/ico/icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/ico/icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/ico/icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/ico/icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/ico/icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/ico/icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/ico/icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/ico/icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/ico/icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/ico/icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/ico/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/ico/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/ico/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/ico/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/ico/icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <title>FRUITS ET LÉGUMES - RNM - prix cours marchéss - </title>
# <link href="https://rnm.franceagrimer.fr/images/vignette.png" rel="image_src">
# <link href="https://rnm.franceagrimer.fr/prix?FRUITS-ET-LEGUMES" rel="canonical"/>
# <meta content="FRUITS ET LÉGUMES : liste des produits du secteur dont les prix sont suivis tous les jours par le RNM sur diff&amp;eacute;rents march&amp;eacute;s." name="description">
# <script>
# window.onscroll = function () {
#   if (window.pageYOffset > 50) {
#   document.getElementById("divup").style.display = "inline";
#   }
#   else {
#   document.getElementById("divup").style.display = "none";
#   }
#  }
# window.onresize = function () {
#   if (window.innerWidth > 1050) {
#   document.getElementById("menug").style.display = "none";
#   menuge=1;
#   }
#  }
# </script>
# </meta></link></head>
# <body>
# <header>
# <div id="divup"><a class="nobordacc" href="#"><img alt="lien up" class="noprint imgup" src="/images/up2.png" title="menu"/></a></div>
# <div class="divportable noprint">
# <table <tr="" style="width:100%;margin:0;padding:0;">
# <td style="margin:0;padding:0"><a class="nobordacc" href="/" target="_top"><img alt="lien accueil" class="logoaccueil" src="/images/logo_rnm_icon.png" style="width:70px" title="RNM.franceagrimer.fr"/></a>
# </td><td><p style="font-weight:normal;"><small><span class="rnmvert">R</span>éseau des <span class="rnmbleu">N</span>ouvelles des <span class="rnmbleu">M</span>archés</small></p><p>Les prix par produit</p>
# </td><td style="width: 30px;"><a class="nobordacc" href="#" onclick="menugeneral()"><img alt="lien accueil" src="/images/mobmenu.png" title="menu"/></a>
# </td></table>
# </div>
# <div class="divtop100 noprint"><div class="divtop"><table class="tabtop">
# <tr>
# <td class="tabtoptd1">
# <a class="logornm" href="/" target="_top"><img alt="lien accueil" class="imglogornm" src="/images/logo_rnm_icon.png" title="RNM.franceagrimer.fr"/></a>
# </td><td class="tabtoptd2"><a class="logornm" href="/" target="_top">
# <p><span class="rnmvert">R</span>éseau des</p>
# <p><span class="rnmbleu">N</span>ouvelles des</p>
# <p><span class="rnmbleu">M</span>archés</p></a>
# </td>
# <td class="tabtoptd3">
# <table class="tabcentrer" style="margin-right: auto;margin-top:3px;margin-bottom:0px;padding:0;min-width:80%;"> <tr>
# <td> <a class="menuprin0" href="bilan_campagne?menu=derniers" target="_top">Bilans de campagne</a> </td>
# <td><a class="menuprin0" href="/rnm/panier_restau_co.shtml" target="_top">Restauration collective</a> </td>
# <td> <a class="menuprin0" href="/rnm/ReseauRNM.shtml" target="_top">Le RNM</a> </td>
# </tr></table>
# <table class="tabcentrer" style="margin-bottom:15px;margin-top:10px;"> <tr>
# <td><a class="menuprin1" href="/prix?SAINOMMAR" target="_top">PRIX PAR MARCHÉ</a></td><td style="width:50px"></td>
# <td><a class="menuprin1" href="/prix?SAINOMPRODUIT" target="_top">PRIX PAR PRODUIT</a></td>
# </tr></table>
# </td>
# </tr>
# </table></div></div>
# <div class="noprint" id="menug">
# <p><a class="menuprin1" href="/prix?SAINOMMAR" target="_top">PRIX PAR MARCHÉ <img alt="lien marchÃ©" src="/images/fleche1.png"/></a></p>
# <p><a class="menuprin1" href="/prix?SAINOMPRODUIT" target="_top">PRIX PAR PRODUIT <img alt="lien produit" src="/images/fleche1.png"/></a></p>
# <p><a class="menuprin0" href="bilan_campagne?menu=derniers" target="_top">Bilans de campagne <img alt="lien bilan" src="/images/fleche1.png"/></a> </p>
# <p><a class="menuprin0" href="/rnm/panier_restau_co.shtml" target="_top">Restauration collective <img alt="lien restauration" src="/images/fleche1.png"/></a></p>
# <p><a class="menuprin0" href="/rnm/ReseauRNM.shtml" target="_top">Le RNM <img alt="lien RNM" src="/images/fleche1.png"/></a></p>
# <div style="clear:both"></div>
# </div>
# <div id="encours"><br/><img alt="En cours" src="/images/attendre.gif" style="display: block; margin: 0 auto;"/><p>requête en cours</p><br/></div>
# </header>
# <main>
# <div id="main">
# <img alt="RNM" class="noweb" src="/images/rnmh80.png" style="margin-right:50px" title="RNM.franceagrimer.fr"/>
# <div class="signet"><a href="/" target="_top"><img alt="home" class="opacite05" src="/images/home16.png"/></a><a href="/prix?SAINOMPRODUIT">&gt; Produits</a> <span class="signet_fil">&gt; Fruits et Légumes</span> <a class="signet_A marsignet" href="/prix?FLEURS---PLANTES-ORNEMENTALES" onclick="attente();">Fleurs &amp; plantes ornementales</a> <a class="signet_A marsignet" href="/prix?PECHE-ET-AQUACULTURE" onclick="attente();">Pêche et aquaculture</a> <a class="signet_A marsignet" href="/prix?BEURRE-OEUF-FROMAGE" onclick="attente();">Beurre Oeuf Fromage</a> <a class="signet_A marsignet" href="/prix?VIANDE" onclick="attente();">Viande</a></div>
# <h1 class="bleu">Fruits et Légumes<small> : prix sur les marchés</small></h1>
# <h3 class="chap_h">Sélectionner un groupe de produits : </h3>
# <div class="listdiv">
# <div class="listsecproduit pro_nivsous1"> <a href="/prix?LEGUMES" onclick="attente();">Légumes</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?SALADES" onclick="attente();">Salades</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?LEGUMES-ET-HERBES-AROMATIQUES" onclick="attente();">Légumes et herbes aromatiques</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?LEGUMES-FRUITS-ET-GRAINES" onclick="attente();">Légumes fruits et graines</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?LEGUMES-TUBERCULES,-RACINES" onclick="attente();">Légumes tubercules, racines</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?LEGUMES-VERTS,-TIGES" onclick="attente();">Légumes verts, tiges</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?LEGUMES-EXOTIQUES" onclick="attente();">Légumes exotiques</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?CHAMPIGNONS" onclick="attente();">Champignons</a> </div>
# </div><div class="listdiv">
# <div class="listsecproduit pro_nivsous1"> <a href="/prix?FRUITS" onclick="attente();">Fruits</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?FRUITS-SECS" onclick="attente();">Fruits secs</a> </div>
# <div class="listsecproduit pro_niv2"> <a href="/prix?FRUITS-FRAIS" onclick="attente();">Fruits frais</a> </div>
# <div class="listsecproduit pro_niv3"> <a href="/prix?BAIES,-PETITS-FRUITS" onclick="attente();">Baies, petits fruits</a> </div>
# <div class="listsecproduit pro_niv3"> <a href="/prix?FRUITS-A-NOYAU" onclick="attente();">Fruits à noyau</a> </div>
# <div class="listsecproduit pro_niv3"> <a href="/prix?FRUITS-A-PEPINS" onclick="attente();">Fruits à pépins</a> </div>
# <div class="listsecproduit pro_niv3"> <a href="/prix?AGRUMES" onclick="attente();">Agrumes</a> </div>
# <div class="listsecproduit pro_niv3"> <a href="/prix?FRUITS-EXOTIQUES-ET-AUTRES" onclick="attente();">Fruits exotiques et autres</a> </div>
# </div>
# <h3 class="chap_h">Sélectionner un produit : </h3>
# <div class="listdiv">
# <div class="listunproduit"> <a href="/prix?ABRICOT" onclick="attente();">Abricot</a> </div>
# <div class="listunproduit"> <a href="/prix?ABRICOT-SEC" onclick="attente();">Abricot sec</a> </div>
# <div class="listunproduit"> <a href="/prix?AIL" onclick="attente();">Ail</a> </div>
# <div class="listunproduit"> <a href="/prix?AILLET" onclick="attente();">Aillet</a> </div>
# <div class="listunproduit"> <a href="/prix?AMANDE" onclick="attente();">Amande</a> </div>
# <div class="listunproduit"> <a href="/prix?ANANAS" onclick="attente();">Ananas</a> </div>
# <div class="listunproduit"> <a href="/prix?ANETH" onclick="attente();">Aneth</a> </div>
# <div class="listunproduit"> <a href="/prix?ANONE" onclick="attente();">Anone</a> </div>
# <div class="listunproduit"> <a href="/prix?ARTICHAUT" onclick="attente();">Artichaut</a> </div>
# <div class="listunproduit"> <a href="/prix?ASPERGE" onclick="attente();">Asperge</a> </div>
# <div class="listunproduit"> <a href="/prix?AUBERGINE" onclick="attente();">Aubergine</a> </div>
# <div class="listunproduit"> <a href="/prix?AVOCAT" onclick="attente();">Avocat</a> </div>
# <div class="listunproduit"> <a href="/prix?BANANE" onclick="attente();">Banane</a> </div>
# <div class="listunproduit"> <a href="/prix?BASILIC" onclick="attente();">Basilic</a> </div>
# <div class="listunproduit"> <a href="/prix?BETTE" onclick="attente();">Bette</a> </div>
# <div class="listunproduit"> <a href="/prix?BETTERAVE-ROUGE" onclick="attente();">Betterave rouge</a> </div>
# <div class="listunproduit"> <a href="/prix?CARAMBOLE" onclick="attente();">Carambole</a> </div>
# <div class="listunproduit"> <a href="/prix?CARDON" onclick="attente();">Cardon</a> </div>
# <div class="listunproduit"> <a href="/prix?CAROTTE" onclick="attente();">Carotte</a> </div>
# <div class="listunproduit"> <a href="/prix?CASSIS" onclick="attente();">Cassis</a> </div>
# <div class="listunproduit"> <a href="/prix?CELERI-BRANCHE" onclick="attente();">Céleri-branche</a> </div>
# <div class="listunproduit"> <a href="/prix?CELERI-RAVE" onclick="attente();">Céleri-rave</a> </div>
# <div class="listunproduit"> <a href="/prix?CEPE" onclick="attente();">Cèpe</a> </div>
# <div class="listunproduit"> <a href="/prix?CERFEUIL" onclick="attente();">Cerfeuil</a> </div>
# <div class="listunproduit"> <a href="/prix?CERISE" onclick="attente();">Cerise</a> </div>
# <div class="listunproduit"> <a href="/prix?CHAMPIGNON-DE-PARIS" onclick="attente();">Champignon de Paris</a> </div>
# <div class="listunproduit"> <a href="/prix?CHANTERELLE" onclick="attente();">Chanterelle</a> </div>
# <div class="listunproduit"> <a href="/prix?CHAYOTTE" onclick="attente();">Chayotte</a> </div>
# <div class="listunproduit"> <a href="/prix?CHICOREE" onclick="attente();">Chicorée</a> </div>
# <div class="listunproduit"> <a href="/prix?CHOU" onclick="attente();">Chou</a> </div>
# <div class="listunproduit"> <a href="/prix?CHOUCHOU" onclick="attente();">Chouchou</a> </div>
# <div class="listunproduit"> <a href="/prix?CHOU-DE-BRUXELLES" onclick="attente();">Chou de bruxelles</a> </div>
# <div class="listunproduit"> <a href="/prix?CHOU-FLEUR" onclick="attente();">Chou fleur</a> </div>
# <div class="listunproduit"> <a href="/prix?CIBOULETTE" onclick="attente();">Ciboulette</a> </div>
# <div class="listunproduit"> <a href="/prix?CITRON" onclick="attente();">Citron</a> </div>
# <div class="listunproduit"> <a href="/prix?CLEMENTINE" onclick="attente();">Clémentine</a> </div>
# <div class="listunproduit"> <a href="/prix?COING" onclick="attente();">Coing</a> </div>
# <div class="listunproduit"> <a href="/prix?CONCOMBRE" onclick="attente();">Concombre</a> </div>
# <div class="listunproduit"> <a href="/prix?CORIANDRE" onclick="attente();">Coriandre</a> </div>
# <div class="listunproduit"> <a href="/prix?CORNICHON" onclick="attente();">Cornichon</a> </div>
# <div class="listunproduit"> <a href="/prix?COULEMELLE" onclick="attente();">Coulemelle</a> </div>
# <div class="listunproduit"> <a href="/prix?COURGE" onclick="attente();">Courge</a> </div>
# <div class="listunproduit"> <a href="/prix?COURGETTE" onclick="attente();">Courgette</a> </div>
# <div class="listunproduit"> <a href="/prix?CRESSON" onclick="attente();">Cresson</a> </div>
# <div class="listunproduit"> <a href="/prix?CROSNE" onclick="attente();">Crôsne</a> </div>
# <div class="listunproduit"> <a href="/prix?DATTE" onclick="attente();">Datte</a> </div>
# <div class="listunproduit"> <a href="/prix?ECHALION" onclick="attente();">Échalion</a> </div>
# <div class="listunproduit"> <a href="/prix?ECHALOTE" onclick="attente();">Échalote</a> </div>
# <div class="listunproduit"> <a href="/prix?ENDIVE" onclick="attente();">Endive</a> </div>
# <div class="listunproduit"> <a href="/prix?EPINARD" onclick="attente();">Épinard</a> </div>
# <div class="listunproduit"> <a href="/prix?ESTRAGON" onclick="attente();">Estragon</a> </div>
# <div class="listunproduit"> <a href="/prix?FENOUIL" onclick="attente();">Fenouil</a> </div>
# <div class="listunproduit"> <a href="/prix?FEVE" onclick="attente();">Fève</a> </div>
# <div class="listunproduit"> <a href="/prix?FIGUE" onclick="attente();">Figue</a> </div>
# <div class="listunproduit"> <a href="/prix?FIGUE-SECHE" onclick="attente();">Figue sèche</a> </div>
# <div class="listunproduit"> <a href="/prix?FRAISE" onclick="attente();">Fraise</a> </div>
# <div class="listunproduit"> <a href="/prix?FRAMBOISE" onclick="attente();">Framboise</a> </div>
# <div class="listunproduit"> <a href="/prix?FRUIT-DE-LA-PASSION" onclick="attente();">Fruit de la passion</a> </div>
# <div class="listunproduit"> <a href="/prix?GINGEMBRE" onclick="attente();">Gingembre</a> </div>
# <div class="listunproduit"> <a href="/prix?GIROLLE" onclick="attente();">Girolle</a> </div>
# <div class="listunproduit"> <a href="/prix?GOMBO" onclick="attente();">Gombo</a> </div>
# <div class="listunproduit"> <a href="/prix?GOYAVE" onclick="attente();">Goyave</a> </div>
# <div class="listunproduit"> <a href="/prix?GRENADE" onclick="attente();">Grenade</a> </div>
# <div class="listunproduit"> <a href="/prix?GRENADILLE" onclick="attente();">Grenadille</a> </div>
# <div class="listunproduit"> <a href="/prix?GRIOTTE" onclick="attente();">Griotte</a> </div>
# <div class="listunproduit"> <a href="/prix?GROSEILLE" onclick="attente();">Groseille</a> </div>
# <div class="listunproduit"> <a href="/prix?GROSEILLE-A-MAQUEREAU" onclick="attente();">Groseille à maquereau</a> </div>
# <div class="listunproduit"> <a href="/prix?HARICOT" onclick="attente();">Haricot</a> </div>
# <div class="listunproduit"> <a href="/prix?HARICOT-VERT" onclick="attente();">Haricot vert</a> </div>
# <div class="listunproduit"> <a href="/prix?IGNAME" onclick="attente();">Igname</a> </div>
# <div class="listunproduit"> <a href="/prix?KAKI" onclick="attente();">Kaki</a> </div>
# <div class="listunproduit"> <a href="/prix?KIWI" onclick="attente();">Kiwi</a> </div>
# <div class="listunproduit"> <a href="/prix?KUMQUATE" onclick="attente();">Kumquate</a> </div>
# <div class="listunproduit"> <a href="/prix?LACTAIRE" onclick="attente();">Lactaire</a> </div>
# <div class="listunproduit"> <a href="/prix?LAITUE" onclick="attente();">Laitue</a> </div>
# <div class="listunproduit"> <a href="/prix?LAURIER" onclick="attente();">Laurier</a> </div>
# <div class="listunproduit"> <a href="/prix?LIME" onclick="attente();">Lime</a> </div>
# <div class="listunproduit"> <a href="/prix?LITCHI" onclick="attente();">Litchi</a> </div>
# <div class="listunproduit"> <a href="/prix?MACHE" onclick="attente();">Mâche</a> </div>
# <div class="listunproduit"> <a href="/prix?MANDARINE" onclick="attente();">Mandarine</a> </div>
# <div class="listunproduit"> <a href="/prix?MANGOUSTAN" onclick="attente();">Mangoustan</a> </div>
# <div class="listunproduit"> <a href="/prix?MANGUE" onclick="attente();">Mangue</a> </div>
# <div class="listunproduit"> <a href="/prix?MANIOC" onclick="attente();">Manioc</a> </div>
# <div class="listunproduit"> <a href="/prix?MARRON" onclick="attente();">Marron</a> </div>
# <div class="listunproduit"> <a href="/prix?MELANGE-SALADES" onclick="attente();">Mélange salades</a> </div>
# <div class="listunproduit"> <a href="/prix?MELON" onclick="attente();">Melon</a> </div>
# <div class="listunproduit"> <a href="/prix?MENTHE" onclick="attente();">Menthe</a> </div>
# <div class="listunproduit"> <a href="/prix?MESCLUN" onclick="attente();">Mesclun</a> </div>
# <div class="listunproduit"> <a href="/prix?MINEOLA" onclick="attente();">Minéola</a> </div>
# <div class="listunproduit"> <a href="/prix?MORILLE" onclick="attente();">Morille</a> </div>
# <div class="listunproduit"> <a href="/prix?MURE" onclick="attente();">Mûre</a> </div>
# <div class="listunproduit"> <a href="/prix?MYRTILLE" onclick="attente();">Myrtille</a> </div>
# <div class="listunproduit"> <a href="/prix?NAVET" onclick="attente();">Navet</a> </div>
# <div class="listunproduit"> <a href="/prix?NECTARINE" onclick="attente();">Nectarine</a> </div>
# <div class="listunproduit"> <a href="/prix?NEFLE" onclick="attente();">Nèfle</a> </div>
# <div class="listunproduit"> <a href="/prix?NOISETTE" onclick="attente();">Noisette</a> </div>
# <div class="listunproduit"> <a href="/prix?NOIX" onclick="attente();">Noix</a> </div>
# <div class="listunproduit"> <a href="/prix?NOIX-DE-COCO" onclick="attente();">Noix de coco</a> </div>
# <div class="listunproduit"> <a href="/prix?OIGNON" onclick="attente();">Oignon</a> </div>
# <div class="listunproduit"> <a href="/prix?ORANGE" onclick="attente();">Orange</a> </div>
# <div class="listunproduit"> <a href="/prix?ORTANIQUE" onclick="attente();">Ortanique</a> </div>
# <div class="listunproduit"> <a href="/prix?OSEILLE" onclick="attente();">Oseille</a> </div>
# <div class="listunproduit"> <a href="/prix?PANAIS" onclick="attente();">Panais</a> </div>
# <div class="listunproduit"> <a href="/prix?PAPAYE" onclick="attente();">Papaye</a> </div>
# <div class="listunproduit"> <a href="/prix?PASTEQUE" onclick="attente();">Pastèque</a> </div>
# <div class="listunproduit"> <a href="/prix?PATATE-DOUCE" onclick="attente();">Patate douce</a> </div>
# <div class="listunproduit"> <a href="/prix?PATISSON" onclick="attente();">Patisson</a> </div>
# <div class="listunproduit"> <a href="/prix?PECHE" onclick="attente();">Pêche</a> </div>
# <div class="listunproduit"> <a href="/prix?PERSIL" onclick="attente();">Persil</a> </div>
# <div class="listunproduit"> <a href="/prix?PHYSALIS" onclick="attente();">Physalis</a> </div>
# <div class="listunproduit"> <a href="/prix?PIED-DE-MOUTON" onclick="attente();">Pied de mouton</a> </div>
# <div class="listunproduit"> <a href="/prix?PIMENT" onclick="attente();">Piment</a> </div>
# <div class="listunproduit"> <a href="/prix?PISSENLIT" onclick="attente();">Pissenlit</a> </div>
# <div class="listunproduit"> <a href="/prix?PITAHAYA" onclick="attente();">Pitahaya</a> </div>
# <div class="listunproduit"> <a href="/prix?PLEUROTE" onclick="attente();">Pleurote</a> </div>
# <div class="listunproduit"> <a href="/prix?POIRE" onclick="attente();">Poire</a> </div>
# <div class="listunproduit"> <a href="/prix?POIREAU" onclick="attente();">Poireau</a> </div>
# <div class="listunproduit"> <a href="/prix?POIS" onclick="attente();">Pois</a> </div>
# <div class="listunproduit"> <a href="/prix?POIVRON" onclick="attente();">Poivron</a> </div>
# <div class="listunproduit"> <a href="/prix?POMELOS" onclick="attente();">Pomelos</a> </div>
# <div class="listunproduit"> <a href="/prix?POMME" onclick="attente();">Pomme</a> </div>
# <div class="listunproduit"> <a href="/prix?POMME-DE-TERRE" onclick="attente();">Pomme de terre</a> </div>
# <div class="listunproduit"> <a href="/prix?POTIRON" onclick="attente();">Potiron</a> </div>
# <div class="listunproduit"> <a href="/prix?PRUNE" onclick="attente();">Prune</a> </div>
# <div class="listunproduit"> <a href="/prix?PRUNEAU" onclick="attente();">Pruneau</a> </div>
# <div class="listunproduit"> <a href="/prix?RADIS" onclick="attente();">Radis</a> </div>
# <div class="listunproduit"> <a href="/prix?RAISIN" onclick="attente();">Raisin</a> </div>
# <div class="listunproduit"> <a href="/prix?RHUBARBE" onclick="attente();">Rhubarbe</a> </div>
# <div class="listunproduit"> <a href="/prix?ROMARIN" onclick="attente();">Romarin</a> </div>
# <div class="listunproduit"> <a href="/prix?ROQUETTE" onclick="attente();">Roquette</a> </div>
# <div class="listunproduit"> <a href="/prix?RUTABAGA" onclick="attente();">Rutabaga</a> </div>
# <div class="listunproduit"> <a href="/prix?SALSIFIS" onclick="attente();">Salsifis</a> </div>
# <div class="listunproduit"> <a href="/prix?SATSUMA" onclick="attente();">Satsuma</a> </div>
# <div class="listunproduit"> <a href="/prix?SAUGE" onclick="attente();">Sauge</a> </div>
# <div class="listunproduit"> <a href="/prix?SCORSONERE" onclick="attente();">Scorsonère</a> </div>
# <div class="listunproduit"> <a href="/prix?SHII-TAKE" onclick="attente();">Shii-take</a> </div>
# <div class="listunproduit"> <a href="/prix?SOJA" onclick="attente();">Soja</a> </div>
# <div class="listunproduit"> <a href="/prix?TARO" onclick="attente();">Taro</a> </div>
# <div class="listunproduit"> <a href="/prix?THYM" onclick="attente();">Thym</a> </div>
# <div class="listunproduit"> <a href="/prix?TOMATE" onclick="attente();">Tomate</a> </div>
# <div class="listunproduit"> <a href="/prix?TOPINAMBOUR" onclick="attente();">Topinambour</a> </div>
# <div class="listunproduit"> <a href="/prix?TROMPETTE-DE-LA-MORT" onclick="attente();">Trompette de la mort</a> </div>
# <div class="listunproduit"> <a href="/prix?TRUFFE" onclick="attente();">Truffe</a> </div>
# </div>
# <br/>
# </div></main><footer><div class="footer noprint" style="margin-top:20px">
# <hr class="hrvert"/>
# <div class="btnbas">
# <a href="/abonne?AJOUTER" rel="nofollow noopener noreferrer" style="font-size: 1.2em;font-weight: bold;">Abonnez-vous</a>
# <a href="/rnm/rnm_adr2.shtml"> Contacts</a>
# <a href="/rnm/infolegal.shtml"> Mentions légales</a>
# <a class="abtnbas" href="#" onclick="window.print()"><img alt="imprimer" src="/images/printer24.png" title="imprimer la page"/></a>
#  Partager
# <a class="abtnbas" href="mailto:?subject=FRUITS%20ET%20L%c3%89GUMES%20-%20RNM%20-%20prix%20cours%20march%c3%a9ss%20-%20&amp;body=Copier%20coller%20l%27URL%20ci-dessous%20dans%20le%20navigateur%0D%0Ahttps%3a%2f%2frnm.franceagrimer.fr%2fprix%3fFRUITS-ET-LEGUMES"><img alt="par mail" class="partage" src="/images/email24.png" title="envoyer le lien par mail"/></a>
# <a class="abtnbas" href="https://www.facebook.com/sharer.php?u=https%3a%2f%2frnm.franceagrimer.fr%2fprix%3fFRUITS-ET-LEGUMES" onclick="window.open(this.href,'', 'menubar=no,toolbar=no,height=500,width=700');return false;" rel="nofollow noopener noreferrer" target="_blank" title="Facebook">
# <img alt="facebook" class="partage" src="/images/facebook24.png" title="partager le lien sur facebook"/></a>
# <a class="abtnbas" href="https://twitter.com/share?url=https%3a%2f%2frnm.franceagrimer.fr%2fprix%3fFRUITS-ET-LEGUMES&amp;text=FRUITS%20ET%20L%c3%89GUMES%20-%20RNM%20-%20prix%20cours%20march%c3%a9ss%20-%20" onclick="javascript:window.open(this.href,'','menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=400,width=700');return false;" rel="nofollow noopener noreferrer" target="_blank" title="Twitter">
# <img alt="twitter" class="partage" src="/images/twitter24.png" title="partager le lien sur twitter"/></a>
# </div></div>
# <div class="chapbas">
# <div class="chapbas_g"><a class="mobile" href="https://RNM.FranceAgriMer.fr" target="_top">https://RNM.FranceAgriMer.fr</a>
# </div>
# <div class="chapbas_d">Le prix des produits alimentaires frais</div></div>
# <div class="divlogo100"><div class="divlogo1"><div class="divlogo">
# <a class="nobord" href="http://www.franceagrimer.fr" rel="noopener" target="_blank"><img alt="FranceAgriMer" class="divlogo_g" src="/images/logo_fam_148.png"/></a>
# <a class="nobord" href="https://agriculture.gouv.fr/" rel="noopener" target="_blank"><img alt="MAA" class="divlogo_d" src="/images/logo_maa_148.png"/></a>
# <p>Le <span class="rnmvert">R</span>éseau des <span class="rnmbleu">N</span>ouvelles des <span class="rnmbleu">M</span>archés est piloté au niveau national par l'établissement public FranceAgriMer.
# La collecte d'informations est réalisée en région par des équipes d'enquêteurs conjoncturistes du Ministère
# de l'Agriculture et de l'Alimentation en DRAAF.</p></div></div></div>
# </footer></body></html>

# %% [markdown]
# In order to fetch the data we want, we had to know the structure of the page itself.
# Here, we notice that each product has its own page which is identified with the __div__ class `listunproduit` and the __href__ `/prix?product`. In odrer to get the prices of the X last months we simply add `&Xmois`at the end of the url. So we simply search for all the urls contained in all the __div__ of the class `listunproduit`.

# %%
table = soup.find_all('div', attrs={'class': 'listunproduit'}) #Listing all the class listunproduit

urls = [] #Initializing a list of all the urls for the product

for produit in table:
    urls.append("https://rnm.franceagrimer.fr"+produit.find('a',href = True)['href']+'&12MOIS') #Fetching all the urls of all the products

N = len(urls)

# %%
print(f"The urls list contains urls like : {urls[0]}")
# Out:
# The urls list contains urls like : https://rnm.franceagrimer.fr/prix?ABRICOT&12MOIS

# %% [markdown]
# The next step is the core of that part. Once we get the urls we need to fecth the prices of all the product. In order to be as fast as possible we use a multithreading technique with 4 threads.
#
# But as we did before, we first need to know the structure of all the pages we visit. So we begin by printing the HTML code of one page. Fortunately all the pages have the same structure.

# %%
page = urllib.request.urlopen(urls[0])
soup = BeautifulSoup(page, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="fr">
# <head>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <link href="/css/basernm.css?051020" rel="stylesheet" type="text/css"/>
# <script async="" src="/css/basernm.js?270919"></script>
# <link href="/ico/icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/ico/icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/ico/icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/ico/icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/ico/icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/ico/icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/ico/icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/ico/icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/ico/icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/ico/icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/ico/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/ico/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/ico/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/ico/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/ico/icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <title>ABRICOT - RNM - prix mensuels - Fruits et Légumes</title>
# <link href="https://rnm.franceagrimer.fr/images/vignette.png" rel="image_src">
# <link href="https://rnm.franceagrimer.fr/prix?ABRICOT&amp;12MOIS" rel="canonical"/>
# <meta content="ABRICOT : Prix moyens mensuels (12 mois) sur différents marchés (production, expédition, gros, détail)." name="description">
# <script>
# window.onscroll = function () {
#   if (window.pageYOffset > 50) {
#   document.getElementById("divup").style.display = "inline";
#   }
#   else {
#   document.getElementById("divup").style.display = "none";
#   }
#  }
# window.onresize = function () {
#   if (window.innerWidth > 1050) {
#   document.getElementById("menug").style.display = "none";
#   menuge=1;
#   }
#  }
# </script>
# </meta></link></head>
# <body>
# <header>
# <div id="divup"><a class="nobordacc" href="#"><img alt="lien up" class="noprint imgup" src="/images/up2.png" title="menu"/></a></div>
# <div id="popup"> </div>
# <div id="unlib">
# <p style="margin:10px 20px;"><button onclick="m12_mobileclose()">Fermer</button></p>
# <p id="libtitre"></p>
# <p id="libmar">marche</p>
# <p> <span id="libpro"></span> <small> (<span id="libunm"></span>) </small> </p>
# <table style="text-align:right">
# <tr><td id="td01"></td><td id="td1">1</td></tr>
# <tr><td id="td02"></td><td id="td2"></td></tr>
# <tr><td id="td03"></td><td id="td3"></td></tr>
# <tr><td id="td04"></td><td id="td4"></td></tr>
# <tr><td id="td05"></td><td id="td5"></td></tr>
# <tr><td id="td06"></td><td id="td6"></td></tr>
# <tr><td id="td07"></td><td id="td7"></td></tr>
# <tr><td id="td08"></td><td id="td8"></td></tr>
# <tr><td id="td09"></td><td id="td9"></td></tr>
# <tr><td id="td010"></td><td id="td10"></td></tr>
# <tr><td id="td011"></td><td id="td11"></td></tr>
# <tr><td id="td012"></td><td id="td12"></td></tr>
# </table> </div>
# <style>div#main,.divtop,.chapbas{max-width:1300px;}</style>
# <div class="divportable noprint">
# <table <tr="" style="width:100%;margin:0;padding:0;">
# <td style="margin:0;padding:0"><a class="nobordacc" href="/" target="_top"><img alt="lien accueil" class="logoaccueil" src="/images/logo_rnm_icon.png" style="width:70px" title="RNM.franceagrimer.fr"/></a>
# </td><td><p style="font-weight:normal;"><small><span class="rnmvert">R</span>éseau des <span class="rnmbleu">N</span>ouvelles des <span class="rnmbleu">M</span>archés</small></p><p>Les prix par produit</p>
# </td><td style="width: 30px;"><a class="nobordacc" href="#" onclick="menugeneral()"><img alt="lien accueil" src="/images/mobmenu.png" title="menu"/></a>
# </td></table>
# </div>
# <div class="divtop100 noprint"><div class="divtop"><table class="tabtop">
# <tr>
# <td class="tabtoptd1">
# <a class="logornm" href="/" target="_top"><img alt="lien accueil" class="imglogornm" src="/images/logo_rnm_icon.png" title="RNM.franceagrimer.fr"/></a>
# </td><td class="tabtoptd2"><a class="logornm" href="/" target="_top">
# <p><span class="rnmvert">R</span>éseau des</p>
# <p><span class="rnmbleu">N</span>ouvelles des</p>
# <p><span class="rnmbleu">M</span>archés</p></a>
# </td>
# <td class="tabtoptd3">
# <table class="tabcentrer" style="margin-right: auto;margin-top:3px;margin-bottom:0px;padding:0;min-width:80%;"> <tr>
# <td> <a class="menuprin0" href="bilan_campagne?menu=derniers" target="_top">Bilans de campagne</a> </td>
# <td><a class="menuprin0" href="/rnm/panier_restau_co.shtml" target="_top">Restauration collective</a> </td>
# <td> <a class="menuprin0" href="/rnm/ReseauRNM.shtml" target="_top">Le RNM</a> </td>
# </tr></table>
# <table class="tabcentrer" style="margin-bottom:15px;margin-top:10px;"> <tr>
# <td><a class="menuprin1" href="/prix?SAINOMMAR" target="_top">PRIX PAR MARCHÉ</a></td><td style="width:50px"></td>
# <td><a class="menuprin1" href="/prix?SAINOMPRODUIT" target="_top">PRIX PAR PRODUIT</a></td>
# </tr></table>
# </td>
# </tr>
# </table></div></div>
# <div class="noprint" id="menug">
# <p><a class="menuprin1" href="/prix?SAINOMMAR" target="_top">PRIX PAR MARCHÉ <img alt="lien marchÃ©" src="/images/fleche1.png"/></a></p>
# <p><a class="menuprin1" href="/prix?SAINOMPRODUIT" target="_top">PRIX PAR PRODUIT <img alt="lien produit" src="/images/fleche1.png"/></a></p>
# <p><a class="menuprin0" href="bilan_campagne?menu=derniers" target="_top">Bilans de campagne <img alt="lien bilan" src="/images/fleche1.png"/></a> </p>
# <p><a class="menuprin0" href="/rnm/panier_restau_co.shtml" target="_top">Restauration collective <img alt="lien restauration" src="/images/fleche1.png"/></a></p>
# <p><a class="menuprin0" href="/rnm/ReseauRNM.shtml" target="_top">Le RNM <img alt="lien RNM" src="/images/fleche1.png"/></a></p>
# <div style="clear:both"></div>
# </div>
# <div id="encours"><br/><img alt="En cours" src="/images/attendre.gif" style="display: block; margin: 0 auto;"/><p>requête en cours</p><br/></div>
# </header>
# <main>
# <div id="main">
# <img alt="RNM" class="noweb" src="/images/rnmh80.png" style="margin-right:50px" title="RNM.franceagrimer.fr"/>
# <div class="signet"><a href="/" target="_top"><img alt="home" class="opacite05" src="/images/home16.png"/></a><a href="/prix?SAINOMPRODUIT">&gt; Produits</a> <a href="/prix?FRUITS-ET-LEGUMES" onclick="attente();">&gt; Fruits et Légumes</a> <a href="/prix?FRUITS" onclick="attente();">&gt; Fruits</a> <a href="/prix?FRUITS-FRAIS" onclick="attente();">&gt; Fruits frais</a> <a href="/prix?FRUITS-A-NOYAU" onclick="attente();">&gt; Fruits à noyau</a> <a href="/prix?ABRICOT" onclick="attente();">&gt; Abricot</a> </div>
# <h1 class="bleu">ABRICOT</h1>
# <h2 style="margin-top:0;text-align:center;">prix moyens mensuels du 01-06-2020 au 31-05-2021</h2>
# <div class="noprint"><div class="form1"><div class="form1_g">
# <form action="/prix" method="post" onsubmit="return date_ok_attente('val1',false)">
# <input name="MENSUEL" type="hidden" value="1"/>
# <input name="ESPECE" type="hidden" value="113"/>
# <table><tr><td>autre date de fin </td><td><input id="val1" name="DATE" size="12" type="text" value=""/></td><td>
# <input type="submit" value="OK"/>
# <input class="noxls" onclick="window.print()" type="button" value="Imprimer"/>
# </td></tr><tr><td><small>(date quelconque dans le mois)</small></td><td><small><strong>JJ-MM-AA </strong>ou<strong> JJMMAA</strong></small></td><td></td></tr></table>
# </form></div> <div class="form1_d">
# <form action="/prix" id="tab" method="post">
# <input name="MENSUEL" type="hidden" value="1"/>
# <input name="ESPECE" type="hidden" value="113"/>
# <input name="LASTDATE" type="hidden" value="31-05-21"/>
# <p class="noxls"> <a class="droit" href="#" onclick="document.getElementById('tab').submit()"><img alt="lien" src="/images/fleche1.png"> Voir dans un tableur : moyennes mensuelles</img></a></p>
# </form>
# <form action="/prix" id="tab1" method="post">
# <input name="HEBDO" type="hidden" value="1"/>
# <input name="ESPECE" type="hidden" value="113"/>
# <input name="LASTDATE" type="hidden" value="29-06-21"/>
# <p class="noxls"> <a class="droit" href="#" onclick="document.getElementById('tab1').submit()"><img alt="lien" src="/images/fleche1.png"/> Voir dans un tableur : moyennes hebdomadaires</a></p>
# </form>
# <p><a class="droit" href="/prix?ABRICOT"><img alt="lien" src="/images/fleche1.png"/> Les dernières cotations</a></p>
# </div></div></div>
# <hr/><p class="rouge" style="font-size:0.96em;font-style:italic">Le système calcule des moyennes arithmétiques : attention, sur la période considérée, une seule cotation est suffisante pour obtenir la moyenne de la période. Lorsqu’un produit a de fortes variations saisonnières, la signification d’un prix moyen sur une périodicité mensuelle peut être faible. Vous pouvez cliquer sur le libellé pour vérifier les cotations prises en compte dans le calcul de la moyenne mensuelle.</p><hr/>
# <p><b>Voir stade de commercialisation : </b><span style="white-space:nowrap"><input checked="" class="checkstade" id="cbsta9" onclick="procheckstade(this,9)" type="checkbox"/>Marché de producteurs</span> <span style="white-space:nowrap"><input checked="" class="checkstade" id="cbsta2" onclick="procheckstade(this,2)" type="checkbox"/>Expédition</span> <span style="white-space:nowrap"><input checked="" class="checkstade" id="cbsta3" onclick="procheckstade(this,3)" type="checkbox"/>Import</span> <span style="white-space:nowrap"><input checked="" class="checkstade" id="cbsta5" onclick="procheckstade(this,5)" type="checkbox"/>Grossistes</span> <span style="white-space:nowrap"><input checked="" class="checkstade" id="cbsta7" onclick="procheckstade(this,7)" type="checkbox"/>Détail</span> </p>
# <p class="noprint"><input id="sellibelle" onclick="prosellibelle();" type="checkbox"/> N'afficher que les libellés contenant ce mot : <input id="sellibnom" onkeyup="prosellibelle()" size="12" type="text" value=""/></p>
# <table class="tabcot" id="tabcotmar">
# <thead>
# <tr><th class="thcot">libellé</th>
# <th class="thcot m12">Juin<br/>2020</th>
# <th class="thcot m12">Juil.<br/>2020</th>
# <th class="thcot m12">Août<br/>2020</th>
# <th class="thcot m12">Septe.<br/>2020</th>
# <th class="thcot m12">Octo.<br/>2020</th>
# <th class="thcot m12">Nove.<br/>2020</th>
# <th class="thcot m12">Déce.<br/>2020</th>
# <th class="thcot m12">Janv.<br/>2021</th>
# <th class="thcot m12">Févr.<br/>2021</th>
# <th class="thcot m12">Mars<br/>2021</th>
# <th class="thcot m12">Avril<br/>2021</th>
# <th class="thcot m12">Mai<br/>2021</th>
# <th class="thcot m12on">Voir</th>
# </tr>
# </thead><tbody>
# <tr class="sta9"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M0096:MARCHE">Marché de Lyon-Corbas carreau : fruits et légumes</a></strong> (cours Marché de producteurs en <span class="euro">€ HT</span>)</td></tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57220961,'')"> ABRICOT Bergeron Rhône-Alpes cat.I 40-45mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.20</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Lyon-Corbas carreau : fruits et légumes","ABRICOT Bergeron Rhône-Alpes cat.I 40-45mm","le kg"," ","2.20"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57220962,'')"> ABRICOT Bergeron Rhône-Alpes cat.I 45-50mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 3.00</td>
# <td class="tdcotr m12"> 2.70</td>
# <td class="tdcotr m12"> 2.50</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Lyon-Corbas carreau : fruits et légumes","ABRICOT Bergeron Rhône-Alpes cat.I 45-50mm","le kg","3.00","2.70","2.50"," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57220963,'')"> ABRICOT Bergeron Rhône-Alpes cat.I 50-55mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.87</td>
# <td class="tdcotr m12"> 2.80</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Lyon-Corbas carreau : fruits et légumes","ABRICOT Bergeron Rhône-Alpes cat.I 50-55mm","le kg"," ","2.87","2.80"," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57220840,'')"> ABRICOT type orangé rouge Rhône-Alpes cat.I 40-45mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.09</td>
# <td class="tdcotr m12"> 2.10</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Lyon-Corbas carreau : fruits et légumes","ABRICOT type orangé rouge Rhône-Alpes cat.I 40-45mm","le kg","2.09","2.10"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57220841,'')"> ABRICOT type orangé rouge Rhône-Alpes cat.I 45-50mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.54</td>
# <td class="tdcotr m12"> 2.55</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Lyon-Corbas carreau : fruits et légumes","ABRICOT type orangé rouge Rhône-Alpes cat.I 45-50mm","le kg","2.54","2.55"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57220842,'')"> ABRICOT type orangé rouge Rhône-Alpes cat.I 50-55mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 3.03</td>
# <td class="tdcotr m12"> 2.79</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Lyon-Corbas carreau : fruits et légumes","ABRICOT type orangé rouge Rhône-Alpes cat.I 50-55mm","le kg","3.03","2.79"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M0058:MARCHE">Marché de Perpignan carreau : fruits et légumes</a></strong> (cours Marché de producteurs en <span class="euro">€ HT</span>)</td></tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(9630058,'')"> ABRICOT Royal Roussillon Roussillon 45-50mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.30</td>
# <td class="tdcotr m12"> 2.00</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Perpignan carreau : fruits et légumes","ABRICOT Royal Roussillon Roussillon 45-50mm","le kg","2.30","2.00"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(9620058,'')"> ABRICOT Royal Roussillon Roussillon cat.I 50-55mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.50</td>
# <td class="tdcotr m12"> 2.50</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Perpignan carreau : fruits et légumes","ABRICOT Royal Roussillon Roussillon cat.I 50-55mm","le kg","2.50","2.50"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57224281,'')"> ABRICOT type orangé rouge Roussillon 40-45mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.00</td>
# <td class="tdcotr m12"> 2.00</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.12</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Perpignan carreau : fruits et légumes","ABRICOT type orangé rouge Roussillon 40-45mm","le kg"," ","2.00","2.00"," "," "," "," "," "," "," "," ","3.12")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57224282,'')"> ABRICOT type orangé rouge Roussillon 45-50mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.19</td>
# <td class="tdcotr m12"> 2.35</td>
# <td class="tdcotr m12"> 2.40</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.70</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Perpignan carreau : fruits et légumes","ABRICOT type orangé rouge Roussillon 45-50mm","le kg","2.19","2.35","2.40"," "," "," "," "," "," "," "," ","3.70")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57224283,'')"> ABRICOT type orangé rouge Roussillon 50-55mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.44</td>
# <td class="tdcotr m12"> 2.50</td>
# <td class="tdcotr m12"> 2.50</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 4.40</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Marché de Perpignan carreau : fruits et légumes","ABRICOT type orangé rouge Roussillon 50-55mm","le kg","2.44","2.50","2.50"," "," "," "," "," "," "," "," ","4.40")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M0010:MARCHE">MIN d'Agen carreau : fruits et légumes</a></strong> (cours Marché de producteurs en <span class="euro">€ HT</span>)</td></tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1840010,'')"> ABRICOT Sud-Ouest cat.I 40-45mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.25</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;MIN d'Agen carreau : fruits et légumes&quot;,&quot;ABRICOT Sud-Ouest cat.I 40-45mm&quot;,&quot;le kg&quot;,&quot; &quot;,&quot;3.25&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1850010,'')"> ABRICOT Sud-Ouest cat.I 45-50mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 4.00</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;MIN d'Agen carreau : fruits et légumes&quot;,&quot;ABRICOT Sud-Ouest cat.I 45-50mm&quot;,&quot;le kg&quot;,&quot;4.00&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M0103:MARCHE">MIN de Cavaillon carreau : fruits et légumes</a></strong> (cours Marché de producteurs en <span class="euro">€ HT</span>)</td></tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57219191,'')"> ABRICOT type orangé rouge Sud-Est 40-45mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.05</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Cavaillon carreau : fruits et légumes","ABRICOT type orangé rouge Sud-Est 40-45mm plateau","le kg"," ","2.05"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57219192,'')"> ABRICOT type orangé rouge Sud-Est 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.55</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 4.00</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Cavaillon carreau : fruits et légumes","ABRICOT type orangé rouge Sud-Est 45-50mm plateau","le kg"," ","2.55"," "," "," "," "," "," "," "," "," ","4.00")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57219193,'')"> ABRICOT type orangé rouge Sud-Est 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.00</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Cavaillon carreau : fruits et légumes","ABRICOT type orangé rouge Sud-Est 50-55mm plateau","le kg"," ","3.00"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M0104:MARCHE">MIN de Châteaurenard carreau : fruits et légumes</a></strong> (cours Marché de producteurs en <span class="euro">€ HT</span>)</td></tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(10930104,'')"> ABRICOT Bergarouge Sud-Est 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.45</td>
# <td class="tdcotr m12"> 2.46</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Bergarouge Sud-Est 45-50mm plateau","le kg","2.45","2.46"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(10940104,'')"> ABRICOT Bergarouge Sud-Est 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.96</td>
# <td class="tdcotr m12"> 2.62</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Bergarouge Sud-Est 50-55mm plateau","le kg","2.96","2.62"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1760104,'')"> ABRICOT Bergeron Sud-Est 40-45mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 1.50</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Bergeron Sud-Est 40-45mm plateau","le kg"," ","1.50"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1770104,'')"> ABRICOT Bergeron Sud-Est 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 1.80</td>
# <td class="tdcotr m12"> 2.50</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Bergeron Sud-Est 45-50mm plateau","le kg","1.80","2.50"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1880104,'')"> ABRICOT Bergeron Sud-Est 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.30</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Bergeron Sud-Est 50-55mm plateau","le kg"," ","2.30"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1420104,'')"> ABRICOT Orangered Sud-Est 40-45mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.05</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Orangered Sud-Est 40-45mm plateau","le kg","2.05"," "," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1300104,'')"> ABRICOT Orangered Sud-Est 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.96</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Orangered Sud-Est 45-50mm plateau","le kg","2.96"," "," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1270104,'')"> ABRICOT Orangered Sud-Est 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 3.51</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Orangered Sud-Est 50-55mm plateau","le kg","3.51"," "," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(1630104,'')"> ABRICOT Orangered Sud-Est 55-60mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 3.80</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT Orangered Sud-Est 55-60mm plateau","le kg","3.80"," "," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57219137,'')"> ABRICOT type orangé rouge Sud-Est 35-40mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 1.25</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT type orangé rouge Sud-Est 35-40mm plateau","le kg"," "," "," "," "," "," "," "," "," "," "," ","1.25")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57218935,'')"> ABRICOT type orangé rouge Sud-Est 40-45mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 1.77</td>
# <td class="tdcotr m12"> 1.70</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 1.90</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT type orangé rouge Sud-Est 40-45mm plateau","le kg","1.77","1.70"," "," "," "," "," "," "," "," "," ","1.90")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57218936,'')"> ABRICOT type orangé rouge Sud-Est 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.39</td>
# <td class="tdcotr m12"> 2.30</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.48</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT type orangé rouge Sud-Est 45-50mm plateau","le kg","2.39","2.30"," "," "," "," "," "," "," "," "," ","2.48")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57218937,'')"> ABRICOT type orangé rouge Sud-Est 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.63</td>
# <td class="tdcotr m12"> 2.54</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.13</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT type orangé rouge Sud-Est 50-55mm plateau","le kg","2.63","2.54"," "," "," "," "," "," "," "," "," ","3.13")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57227606,'')"> ABRICOT type orangé rouge Sud-Est 55-60mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.73</td>
# <td class="tdcotr m12"> 2.60</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT type orangé rouge Sud-Est 55-60mm plateau","le kg","2.73","2.60"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57207591,'')"> ABRICOT type orange Sud-Est 40-45mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 1.50</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT type orange Sud-Est 40-45mm plateau","le kg"," ","1.50"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57207592,'')"> ABRICOT type orange Sud-Est 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 1.83</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT type orange Sud-Est 45-50mm plateau","le kg"," ","1.83"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57215726,'')"> ABRICOT type orange Sud-Est 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.00</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT type orange Sud-Est 50-55mm plateau","le kg"," ","2.00"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57227687,'')"> ABRICOT variétés tardives Sud-Est 40-45mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 1.85</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT variétés tardives Sud-Est 40-45mm plateau","le kg"," ","1.85"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57220979,'')"> ABRICOT variétés tardives Sud-Est 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.28</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT variétés tardives Sud-Est 45-50mm plateau","le kg"," ","2.28"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta9"><td class="tdcotl"><a href="#" onclick="histo_lib(57220980,'')"> ABRICOT variétés tardives Sud-Est 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.41</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Châteaurenard carreau : fruits et légumes","ABRICOT variétés tardives Sud-Est 50-55mm plateau","le kg"," ","2.41"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta2"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M0047:MARCHE">Bassin Auvergne Rhône-Alpes : fruits d'été</a></strong> (cours Expédition en <span class="euro">€ HT</span>)</td></tr>
# <tr class="sta2"><td class="tdcotl"><a href="#" onclick="histo_lib(8840046,'')"> ABRICOT Bergarouge Rhône-Alpes cat.I 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.50</td>
# <td class="tdcotr m12"> 2.43</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;Bassin Auvergne Rhône-Alpes : fruits d'été&quot;,&quot;ABRICOT Bergarouge Rhône-Alpes cat.I 45-50mm plateau&quot;,&quot;le kg&quot;,&quot;2.50&quot;,&quot;2.43&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# <tr class="sta2"><td class="tdcotl"><a href="#" onclick="histo_lib(8850046,'')"> ABRICOT Bergarouge Rhône-Alpes cat.I 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.80</td>
# <td class="tdcotr m12"> 2.69</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;Bassin Auvergne Rhône-Alpes : fruits d'été&quot;,&quot;ABRICOT Bergarouge Rhône-Alpes cat.I 50-55mm plateau&quot;,&quot;le kg&quot;,&quot;2.80&quot;,&quot;2.69&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# <tr class="sta2"><td class="tdcotl"><a href="#" onclick="histo_lib(9500046,'')"> ABRICOT Bergeron Rhône-Alpes cat.I 40-45mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.01</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;Bassin Auvergne Rhône-Alpes : fruits d'été&quot;,&quot;ABRICOT Bergeron Rhône-Alpes cat.I 40-45mm plateau&quot;,&quot;le kg&quot;,&quot; &quot;,&quot;2.01&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# <tr class="sta2"><td class="tdcotl"><a href="#" onclick="histo_lib(9510046,'')"> ABRICOT Bergeron Rhône-Alpes cat.I 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.53</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;Bassin Auvergne Rhône-Alpes : fruits d'été&quot;,&quot;ABRICOT Bergeron Rhône-Alpes cat.I 45-50mm plateau&quot;,&quot;le kg&quot;,&quot; &quot;,&quot;2.53&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# <tr class="sta2"><td class="tdcotl"><a href="#" onclick="histo_lib(9520046,'')"> ABRICOT Bergeron Rhône-Alpes cat.I 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.65</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;Bassin Auvergne Rhône-Alpes : fruits d'été&quot;,&quot;ABRICOT Bergeron Rhône-Alpes cat.I 50-55mm plateau&quot;,&quot;le kg&quot;,&quot; &quot;,&quot;2.65&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# <tr class="sta2"><td class="tdcotl"><a href="#" onclick="histo_lib(57225659,'')"> ABRICOT Bergeval Rhône-Alpes cat.I 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.50</td>
# <td class="tdcotr m12"> 2.43</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;Bassin Auvergne Rhône-Alpes : fruits d'été&quot;,&quot;ABRICOT Bergeval Rhône-Alpes cat.I 45-50mm plateau&quot;,&quot;le kg&quot;,&quot;2.50&quot;,&quot;2.43&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# <tr class="sta2"><td class="tdcotl"><a href="#" onclick="histo_lib(57225660,'')"> ABRICOT Bergeval Rhône-Alpes cat.I 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.79</td>
# <td class="tdcotr m12"> 2.69</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick="m12_mobile(&quot;Bassin Auvergne Rhône-Alpes : fruits d'été&quot;,&quot;ABRICOT Bergeval Rhône-Alpes cat.I 50-55mm plateau&quot;,&quot;le kg&quot;,&quot;2.79&quot;,&quot;2.69&quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;,&quot; &quot;)" type="button" value="..."/></td>
# </tr>
# ...
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(5780201,'')"> ABRICOT U.E. biologique <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 3.48</td>
# <td class="tdcotr m12"> 3.14</td>
# <td class="tdcotr m12"> 4.80</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.79</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Rungis : fruits et légumes bio","ABRICOT U.E. biologique","le kg","3.48","3.14","4.80"," "," "," "," "," "," "," "," ","3.79")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M0027:MARCHE">MIN de Strasbourg : fruits et légumes</a></strong> (cours Grossistes en <span class="euro">€ HT</span>)</td></tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(57207664,'')"> ABRICOT Bergarouge France cat.I 40-45mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.04</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Strasbourg : fruits et légumes","ABRICOT Bergarouge France cat.I 40-45mm","le kg"," ","3.04"," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(6340027,'')"> ABRICOT Espagne cat.I 40-45mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 1.65</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Strasbourg : fruits et légumes","ABRICOT Espagne cat.I 40-45mm","le kg","1.65"," "," "," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(6600027,'')"> ABRICOT Espagne cat.I 45-50mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.08</td>
# <td class="tdcotr m12"> 1.97</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 6.65</td>
# <td class="tdcotr m12"> 2.45</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Strasbourg : fruits et légumes","ABRICOT Espagne cat.I 45-50mm","le kg","2.08","1.97"," "," "," "," "," "," "," "," ","6.65","2.45")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(57231058,'')"> ABRICOT Espagne cat.I 55-60mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.80</td>
# <td class="tdcotr m12"> 3.15</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Strasbourg : fruits et légumes","ABRICOT Espagne cat.I 55-60mm","le kg"," "," "," "," "," "," "," "," "," "," ","3.80","3.15")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(1500027,'')"> ABRICOT France cat.I 45-50mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 3.31</td>
# <td class="tdcotr m12"> 3.34</td>
# <td class="tdcotr m12"> 3.50</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.57</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Strasbourg : fruits et légumes","ABRICOT France cat.I 45-50mm","le kg","3.31","3.34","3.50"," "," "," "," "," "," "," "," ","3.57")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(1510027,'')"> ABRICOT France cat.I 50-55mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.71</td>
# <td class="tdcotr m12"> 3.78</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Strasbourg : fruits et légumes","ABRICOT France cat.I 50-55mm","le kg"," ","3.71","3.78"," "," "," "," "," "," "," "," "," ")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M0066:MARCHE">MIN de Toulouse : fruits et légumes</a></strong> (cours Grossistes en <span class="euro">€ HT</span>)</td></tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(17660066,'')"> ABRICOT Espagne cat.I 45-50mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.62</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Toulouse : fruits et légumes","ABRICOT Espagne cat.I 45-50mm plateau","le kg"," "," "," "," "," "," "," "," "," "," "," ","2.62")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(32450066,'')"> ABRICOT Espagne cat.I 50-55mm plateau <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.30</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Toulouse : fruits et légumes","ABRICOT Espagne cat.I 50-55mm plateau","le kg"," "," "," "," "," "," "," "," "," "," "," ","3.30")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(49800066,'')"> ABRICOT France cat.I 40-45mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.58</td>
# <td class="tdcotr m12"> 2.30</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 2.80</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Toulouse : fruits et légumes","ABRICOT France cat.I 40-45mm","le kg","2.58","2.30"," "," "," "," "," "," "," "," "," ","2.80")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(57207704,'')"> ABRICOT France cat.I 45-50mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.84</td>
# <td class="tdcotr m12"> 2.61</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.73</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Toulouse : fruits et légumes","ABRICOT France cat.I 45-50mm","le kg","2.84","2.61"," "," "," "," "," "," "," "," "," ","3.73")' type="button" value="..."/></td>
# </tr>
# <tr class="sta5"><td class="tdcotl"><a href="#" onclick="histo_lib(57207705,'')"> ABRICOT France cat.I 50-55mm <small>(le kg)</small> </a></td>
# <td class="tdcotr m12"> 2.99</td>
# <td class="tdcotr m12"> 2.89</td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 3.90</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("MIN de Toulouse : fruits et légumes","ABRICOT France cat.I 50-55mm","le kg","2.99","2.89"," "," "," "," "," "," "," "," "," ","3.90")' type="button" value="..."/></td>
# </tr>
# <tr class="sta7"><td class="tdcotcolspan" colspan="13"><strong><a href="/prix?M2503:MARCHE">Fruits France DETAIL GMS</a></strong> (cours Détail en <span class="euro">€ TTC</span>)</td></tr>
# <tr class="sta7"><td class="tdcotl"><a href="#" onclick="histo_lib(57231104,'')"> ABRICOT hors Fr. 45-50mm vrac <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 4.91</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Fruits France DETAIL GMS","ABRICOT hors Fr. 45-50mm vrac","le kg"," "," "," "," "," "," "," "," "," "," "," ","4.91")' type="button" value="..."/></td>
# </tr>
# <tr class="sta7"><td class="tdcotl"><a href="#" onclick="histo_lib(57201475,'')"> ABRICOT hors Fr. barq.1kg <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 4.16</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Fruits France DETAIL GMS","ABRICOT hors Fr. barq.1kg","le kg"," "," "," "," "," "," "," "," "," "," "," ","4.16")' type="button" value="..."/></td>
# </tr>
# <tr class="sta7"><td class="tdcotl"><a href="#" onclick="histo_lib(57201476,'')"> ABRICOT hors Fr. biologique <small>(le kg)</small> </a></td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12">  </td>
# <td class="tdcotr m12"> 6.68</td>
# <td class="tdcotr m12on"><input class="bm12" onclick='m12_mobile("Fruits France DETAIL GMS","ABRICOT hors Fr. biologique","le kg"," "," "," "," "," "," "," "," "," "," "," ","6.68")' type="button" value="..."/></td>
# </tr>
# </tbody>
# </table>
# <script>function m12_mobileinit(libtitre,m1,m2,m3,m4,m5,m6,m7,m8,m9,m10,m11,m12)
#  {
#  document.getElementById("libtitre").innerHTML = libtitre;
#  document.getElementById("td01").innerHTML = m1;
#  document.getElementById("td02").innerHTML = m2;
#  document.getElementById("td03").innerHTML = m3;
#  document.getElementById("td04").innerHTML = m4;
#  document.getElementById("td05").innerHTML = m5;
#  document.getElementById("td06").innerHTML = m6;
#  document.getElementById("td07").innerHTML = m7;
#  document.getElementById("td08").innerHTML = m8;
#  document.getElementById("td09").innerHTML = m9;
#  document.getElementById("td010").innerHTML = m10;
#  document.getElementById("td011").innerHTML = m11;
#  document.getElementById("td012").innerHTML = m12;
#  }
#
# m12_mobileinit("prix moyens mensuels du 01-06-2020 au 31-05-2021","Juin 2020","Juil. 2020","Août 2020","Septe. 2020","Octo. 2020","Nove. 2020","Déce. 2020","Janv. 2021","Févr. 2021","Mars 2021","Avril 2021","Mai 2021")</script>
# <br/>
# </div></main><footer><div class="footer noprint" style="margin-top:20px">
# <hr class="hrvert"/>
# <div class="btnbas">
# <a href="/abonne?AJOUTER" rel="nofollow noopener noreferrer" style="font-size: 1.2em;font-weight: bold;">Abonnez-vous</a>
# <a href="/rnm/rnm_adr2.shtml"> Contacts</a>
# <a href="/rnm/infolegal.shtml"> Mentions légales</a>
# <a class="abtnbas" href="#" onclick="window.print()"><img alt="imprimer" src="/images/printer24.png" title="imprimer la page"/></a>
#  Partager
# <a class="abtnbas" href="mailto:?subject=ABRICOT%20-%20RNM%20-%20prix%20mensuels%20-%20Fruits%20et%20L%c3%a9gumes&amp;body=Copier%20coller%20l%27URL%20ci-dessous%20dans%20le%20navigateur%0D%0Ahttps%3a%2f%2frnm.franceagrimer.fr%2fprix%3fABRICOT%26%2338%3b12MOIS"><img alt="par mail" class="partage" src="/images/email24.png" title="envoyer le lien par mail"/></a>
# <a class="abtnbas" href="https://www.facebook.com/sharer.php?u=https%3a%2f%2frnm.franceagrimer.fr%2fprix%3fABRICOT%26%2338%3b12MOIS" onclick="window.open(this.href,'', 'menubar=no,toolbar=no,height=500,width=700');return false;" rel="nofollow noopener noreferrer" target="_blank" title="Facebook">
# <img alt="facebook" class="partage" src="/images/facebook24.png" title="partager le lien sur facebook"/></a>
# <a class="abtnbas" href="https://twitter.com/share?url=https%3a%2f%2frnm.franceagrimer.fr%2fprix%3fABRICOT%26%2338%3b12MOIS&amp;text=ABRICOT%20-%20RNM%20-%20prix%20mensuels%20-%20Fruits%20et%20L%c3%a9gumes" onclick="javascript:window.open(this.href,'','menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=400,width=700');return false;" rel="nofollow noopener noreferrer" target="_blank" title="Twitter">
# <img alt="twitter" class="partage" src="/images/twitter24.png" title="partager le lien sur twitter"/></a>
# </div></div>
# <div class="chapbas">
# <div class="chapbas_g"><a class="mobile" href="https://RNM.FranceAgriMer.fr" target="_top">https://RNM.FranceAgriMer.fr</a>
# </div>
# <div class="chapbas_d">Le prix des produits alimentaires frais</div></div>
# <div class="divlogo100"><div class="divlogo1"><div class="divlogo">
# <a class="nobord" href="http://www.franceagrimer.fr" rel="noopener" target="_blank"><img alt="FranceAgriMer" class="divlogo_g" src="/images/logo_fam_148.png"/></a>
# <a class="nobord" href="https://agriculture.gouv.fr/" rel="noopener" target="_blank"><img alt="MAA" class="divlogo_d" src="/images/logo_maa_148.png"/></a>
# <p>Le <span class="rnmvert">R</span>éseau des <span class="rnmbleu">N</span>ouvelles des <span class="rnmbleu">M</span>archés est piloté au niveau national par l'établissement public FranceAgriMer.
# La collecte d'informations est réalisée en région par des équipes d'enquêteurs conjoncturistes du Ministère
# de l'Agriculture et de l'Alimentation en DRAAF.</p></div></div></div>
# </footer></body></html>

# %% [markdown]
# As we can see, prices are contained in a __table__ of the class `tabcotmar`. So for each page we fetch the code of that special table and then the figures are contained in __tr__ of class `tdcotr m12` themselves contained in __td__ of the class `tdcotl`.

# %%
produits = []

n_thread = 4 
def getPrice(tid):
    i_start = int(i*N/n_thread)
    i_end = min(N,int((i+1)*N/n_thread))
    for k in range(i_start,i_end):
        url = urls[k]
        page = urllib.request.urlopen(url)
        soup = BeautifulSoup(page, 'html.parser')
        table = soup.find('table',attrs={'id' : 'tabcotmar'})
        for line in table.find('tbody').find_all('tr'):
            location_title = line.find('td', attrs={'class' : 'tdcotcolspan'})
            if location_title == None:
                produit = line.find('td',attrs={'class' : 'tdcotl'})
                prix = line.find_all('td',attrs={'class' : 'tdcotr m12'})
                produits.append([produit.getText(),prix[0].getText(),
                                 prix[1].getText(),prix[2].getText(),
                                 prix[3].getText(),prix[4].getText(),
                                 prix[5].getText(),prix[6].getText(),
                                 prix[7].getText(),prix[8].getText(),
                                 prix[9].getText(),prix[10].getText(),
                                 prix[11].getText()])

# %%
class myThread (threading.Thread):
    def __init__(self, threadID,name, counter):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.name = name
        self.counter = counter
    def run(self):
        getPrice(self.threadID)

# %%
threads = [myThread(i,"T"+str(i),i) for i in range(n_thread)]
print(threads)
for i in range(n_thread):
    threads[i].start()
for thread in threads:
    thread.join()
# Out:
# [<myThread(T0, initial)>, <myThread(T1, initial)>, <myThread(T2, initial)>, <myThread(T3, initial)>]

# %%
print("The data we gathered look like this :")
print(produits[0])
# Out:
# The data we gathered look like this :
# [' CLÉMENTINE Méditerranée biologique tout-calibre (le kg) ', ' \xa0', ' \xa0', ' \xa0', ' \xa0', ' \xa0', ' 3.71', ' 3.70', ' 3.70', ' \xa0', ' \xa0', ' \xa0', ' \xa0']

# %% [markdown]
# We notice that tha data contains a lot of __'\xa0'__ which means that a lot of data are missing which is due to the fact that the prices are note stated every month. In order to deal with this problem we need to fill the data. That point will be described in an other notebook contained in __`./programms/data_computing`__.

# %%
tableau = np.array(produits)
print("Creating csv file")
pd.DataFrame(tableau).to_csv("prix3.csv",header = ["Produit","Prix 1","Prix 2","Prix 3","Prix 4","Prix 5","Prix 6","Prix 7","Prix 8","Prix 9","Prix 10","Prix 11","Prix 12"],sep=";")
print("Done")
# Out:
# Creating csv file
# Done
